# %% [markdown]
# #1. Zadání
#
# Vytvořte třídu Člověk, která bude mít atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int
# 4.   email:str
# 5. adresa:str
# 6. pojišťovna:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této osobě

# %%
class Clovek:
  # Každé zvíře má své jméno a hmotnost
    def __init__(self,jmeno:str,prijmeni,telefon,email,adresa,pojistovna ):
        self.jmeno = jmeno
        self.prijmeni=prijmeni
        self.telefon=telefon
        self.email=email
        self.adresa=adresa
        self.pojistovna=pojistovna

    def get_jmeno(self):
        return self.jmeno
    def set_jmeno(self,nove_jmeno):
        self.jmeno = nove_jmeno
        print("Jméno bylo změněno")

    def get_prijemni(self):
        return self.prijmeni
    def set_prijmeni(self,nove_prijmeni):
        self.prijmeni = nove_prijmeni
        print("Prijmeni bylo změněno")

    def get_telefon(self):
        return self.telefon
    def set_telefon(self,nove_telefon):
        self.telefon = nove_telefon
        print("Telefonní číslo bylo změněno")

    def get_email(self):
        return self.email
    def set_email(self,nove_email):
        self.email = nove_email
        print("Email byl změněn")

    def get_adresa(self):
        return self.adresa
    def set_adresa(self,nove_adresa):
        self.adresa = nove_adresa
        print("Adresa byla změněna")

    def get_pojistovna(self):
        return self.pojistovna
    def set_pojistovna(self,nove_pojistovna):
        self.pojistovna = nove_pojistovna
        print("Pojistovna byla změněna")

    def __str__(self):
        return f"""
        Jméno: {self.jmeno} 
        Příjmení: {self.prijmeni} 
        Telefon: {self.telefon} 
        Email: {self.email} 
        Adresa: {self.adresa} 
        Pojišťovna: {self.pojistovna}
"""
        
clovek1 = Clovek("Aneta","třetí",181926296,"ante@seznam.cz","sklářská 88","VZP")
clovek2 = Clovek("a","b",123456789,"c","d","STK")
print(clovek1)
clovek1.set_prijmeni("druhá")
print(clovek1)
print(clovek1.get_jmeno())
print(clovek1.__jmeno)
# Out:
#         Jméno: Aneta
#         Příjmení: třetí
#         Telefon: 181926296
#         Email: ante@seznam.cz
#         Adresa: sklářská 88
#         Pojišťovna: VZP
#
# Prijmeni bylo změněno
#
#         Jméno: Aneta
#         Příjmení: druhá
#         Telefon: 181926296
#         Email: ante@seznam.cz
#         Adresa: sklářská 88
#         Pojišťovna: VZP
#
# Aneta
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 63
#      61 print(clovek1)
#      62 print(clovek1.get_jmeno())
# ---> 63 print(clovek1.__jmeno)
#
# AttributeError: 'Clovek' object has no attribute '__jmeno'

# %%
# Out:
# aneta
# Jméno změněno.
# Karel
#
# Jméno: Karel
# Prijmeni: a
# Telefon: 456
# Email: ah@as.cz
# Adresa: VZP
# Pojistovna: VZP
# Mesto: Kladno

# %% [markdown]
# #2. Zadání
#
# upravte třídu Člověk tak, abyste ošetřili následující atributy:
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:str
#
# Upravte metody, které budou moc měnit tyto atributy i s aplikovanými omezeními.

# %%
class Clovek:
  #TODO
  # Každé zvíře má své jméno a hmotnost
    def __init__(self,jmeno:str,prijmeni,telefon,email,adresa,pojistovna ):
        self.jmeno = jmeno
        self.prijmeni=prijmeni
        self.telefon=telefon
        self.email=email
        self.adresa=adresa
        self.pojistovna=pojistovna

    def get_jmeno(self):
        return self.jmeno
    def set_jmeno(self,nove_jmeno):
        self.jmeno = nove_jmeno
        print("Jméno bylo změněno")

    def get_prijemni(self):
        return self.prijmeni
    def set_prijmeni(self,nove_prijmeni):
        self.prijmeni = nove_prijmeni
        print("Prijmeni bylo změněno")

    def get_telefon(self):
        return self.telefon
    def set_telefon(self,nove_telefon):
        if telefon <1000000000 or telefon  >999999:
            print("neplatné číslo")
        else:    
            self.telefon = nove_telefon
            print("Telefonní číslo bylo změněno")

    def get_email(self):
        return self.email
    def set_email(self,nove_email):
        self.email = nove_email
        print("Email byl změněn")

    def get_adresa(self):
        return self.adresa
    def set_adresa(self,nove_adresa):
        self.adresa = nove_adresa
        print("Adresa byla změněna")

    def get_pojistovna(self):
        return self.pojistovna
    def set_pojistovna(self,nove_pojistovna):
        self.pojistovna = nove_pojistovna
        print("Pojistovna byla změněna")

    def __str__(self):
        return f"""
        Jméno: {self.jmeno} 
        Příjmení: {self.prijmeni} 
        Telefon: {self.telefon} 
        Email: {self.email} 
        Adresa: {self.adresa} 
        Pojišťovna: {self.pojistovna}
"""
cislo = int(input("zadej nové číslo"))
email = input("zadej nový email")        
clovek1 = Clovek("cigan","třetí",181926296,"ant@seznam.cz","sklářská 88","VZP")

print(clovek1)
clovek1.set_telefon(cislo)
clovek1.set_email(email)
print(clovek1)
# Out:
#         Jméno: cigan
#         Příjmení: třetí
#         Telefon: 181926296
#         Email: ant@seznam.cz
#         Adresa: sklářská 88
#         Pojišťovna: VZP
#
# Telefonní číslo bylo změněno
# Email byl změněn
#
#         Jméno: cigan
#         Příjmení: třetí
#         Telefon: 455
#         Email: 888
#         Adresa: sklářská 88
#         Pojišťovna: VZP

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich

# %% [markdown]
# #3. Zadání
#
# Vytvořte třídu pojištovna, která bude mít atributy:
#
#
# 1.   název:str
# 2.   zkratkaPojištovny:str (maximálně 3 znaky)
# 3. sídlo:str
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše o této pojišťovně.

# %%
class Pojistovna:
  #TODO

# %%
#Zde vytvořte alespoň 2 pojišťovny a zkuste si všechny metody na jedné z nich

# %% [markdown]
# #4. Zadání
#
# Upravte třídu Člověk tak, aby atribut pojišťovna byl vložen jako třída Pojišťovna
#
#
# 1.   jméno:str
# 2.   příjmení:str
# 3.   telefon:int (maximálně 9 znaků)
# 4.   email:str (musí obsahovat @)
# 5. adresa:str
# 6. pojišťovna:class(Pojišťovna)
#
# Upravte metodu, která vám vypíše vše o této osobě tak, aby Vám také vypsala všechny informace o dané pojišťovně

# %%
class Clovek:
  #TODO

# %%
#Zde vytvořte alespoň 2 lidi a zkuste si všechny metody na jedné z nich
print(karel)

# %% [markdown]
# Ukázka Výstupu:
# ```
# Telefon, který jste zadali je neplatný
# Email, který jste zadali je neplatný
#
#         Jméno: Karel
#         Příjmení: Hympa
#         Telefon:
#         Email:
#         Adresa: Svatojánská 36
#         Pojišťovna: VZP
#
#
#         Jméno: Jarda
#         Příjmení: Klomajz
#         Telefon: 987654321
#         Email: Jarda@seznam.cz
#         Adresa: Svatojánská 37
#         Pojišťovna:
#         Název: Všeobecná pojišťovna
#         Zkratka: VZP
#         Sídlo: Armádní 93
# ```

# %% [markdown]
# # Počasí
#
# Vytvořte třídu Pocasi, která bude mít atributy:
#
# 1.   vítr:float
# 2.   povetrnostniPodminky:str
# 3.   teplota:float
# 4.   vlhkost:float
#
# Vytvořte metody, které budou moc získávat a měnit tyto atributy. Také vytvořte metodu, která vám vypíše vše tomto počasí

# %%
class Pocasi:
    #TODO

# %%
#Zde vytvořte alespoň 2 záznamy počasí a zkuste si všechny metody na jedné z nich

# %% [markdown]
# Ukázka Výstupu:
#
# ```
# Rychlost větru: 17 km/h
# Teplota: 18 °C
# Vlhost vzduchu: 54 %
# Počasí: Zataženo
# ```

# %% [markdown]
# # Počasí
# Upravte třídu Pocasi, aby přijímala Enum (na výběr z: Slunečno, zataženo, bouřky atd.)
